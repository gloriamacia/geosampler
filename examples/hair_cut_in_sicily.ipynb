# %%
from sample import *

# %%
s = Sampler(api_key="AIzaSyCMxTwdZjKZLgavf0Nx-qHE89daaYT0ZvE", language='en', region='it', type_='hair_care')

# %%
population = s.nearby_search(locations=['38.115, 13.361', '38.121, 13.357', '38.116, 13.356'], extra_details=True)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Retrieving population at location: 38.115, 13.361
# page 1
# page 2
# page 3
#  33%|███▎      | 1/3 [00:09<00:19,  9.74s/it]
# Retrieving population at location: 38.121, 13.357
# page 1
# page 2
# page 3
#  67%|██████▋   | 2/3 [00:19<00:09,  9.75s/it]
# Retrieving population at location: 38.116, 13.356
# page 1
# page 2
# page 3
# 100%|██████████| 3/3 [00:29<00:00,  9.70s/it]

# %%
population.shape
# Out:
# (92, 14)

# %%
population.head(3)
# Out:
#                       place_id                      name  \
# 0  ChIJY-OKok_lGRMR4rqa9Ax7aaY  Giuseppe Gioeli Barbiere
# 1  ChIJN14Ds4vlGRMR_BChaNsI_HY    Patricia'S Hair Saloon
# 2  ChIJ6wZAMf3lGRMRjvZefgUQXF8    Piero Coiffeur Barbier
#
#                               vicinity  geometry.location.lat  \
# 0  Via Vittorio Emanuele, 313, Palermo              38.115640
# 1      Via del Ponticello, 20, Palermo              38.113838
# 2       Via del Ponticello, 9, Palermo              38.114105
#
#    geometry.location.lng                                              types  \
# 0              13.361190  [hair_care, health, point_of_interest, establi...
# 1              13.361757      [hair_care, point_of_interest, establishment]
# 2              13.362232      [hair_care, point_of_interest, establishment]
#
#    rating  user_ratings_total international_phone_number  \
# 0     5.0               116.0           +39 328 021 0019
# 1     3.0                 1.0                        NaN
# ...

# %%
random_sample = s.random_sample(n=30)
print(random_sample.shape[0])
random_sample.head(3)
# Out:
# 30
#                        place_id                           name  \
# 20  ChIJrTn5t2DvGRMRnmp748I8kfU          Barbiere Da Guglielmo
# 53  ChIJUzdcjl7vGRMRZ0V1eNELo4E  Figaro Di Trudettino Giuseppe
# 65  ChIJQ5Ff_5jvGRMRssREP9o7LMo       UNI.CO Hair & Beauty Lab
#
#                                vicinity  geometry.location.lat  \
# 20       Via Cappuccinelle, 33, Palermo              38.116948
# 53  Via Pignatelli Aragona, 92, Palermo              38.121279
# 65        Piazza Sant'Oliva, 5, Palermo              38.123300
#
#     geometry.location.lng                                              types  \
# 20              13.353637  ['hair_care', 'health', 'point_of_interest', '...
# 53              13.353860  ['hair_care', 'health', 'point_of_interest', '...
# 65              13.353923  ['hair_care', 'health', 'store', 'point_of_int...
#
#     rating  user_ratings_total international_phone_number  \
# 20     NaN                 NaN                        NaN
# ...

# %%
m = s.map(location=(38.115, 13.361), datasets=[population, random_sample], colors=['red', 'blue'], icons=['fa-scissors']*2, colzoom_start=14)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
population.to_csv('population_hair_cut_in_sicily.csv', index=False)
random_sample.to_csv('random_sample_hair_cut_in_sicily.csv', index=False)

# %%
m.save('map_hair_cut_in_sicily.html')
